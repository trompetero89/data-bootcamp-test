# %% [markdown]
# <a href="https://colab.research.google.com/github/trompetero89/data-bootcamp-test/blob/main/Code_Challenge_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Bootcamp Selection Challenge
# #####In this challenge you will calculate various KPIs using a car based dataset, each question will have a single correct answer that will be evaluated through automated unit testing. Use the dictionary provided below to fill in your answers, each question will state the format required for the answer and examples are provided so you know how properly fill the answer dictionary.
# #####**Use the dataset "as is" and do not perform any data cleaning or modify it in any way, doing so could make you answer all your questions incorrectly. Do not modify the structure of the answer dictionary.**
#
# #####When you finish this challenge please upload both your notebook and your answer dictionary in pickle format to a public github repository submit their URL to the [google form](https://forms.gle/wWysZEMkoZsjB11Y7) that was provided to you.
#
# ##### Some unit tests are provided at the end of this notebook to help you verify your answers are in the correct format, however they will not test everything.

# %%
#Use this dictionary to store your answers in the correct format in the cells below , do not modify the keys
answer_dict =  {"Q1" : None,
                "Q2" : None,
                "Q3" : None,
                "Q4" : None,
                "Q5" : None,
                "Q6" : None,
                "Q7" : None}

# %% [markdown]
# ##Reading the dataset
# #####An example is provided to read the dataset using [pandas](https://pandas.pydata.org/), while we reccommend using pandas you may use any python library to solve this challenge.

# %%
import pandas as pd
import numpy as np
url='https://drive.google.com/file/d/1PCJ7ltluquoXKi6MYTPMfwZQNI_-MIFP/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)

# %%
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
#  14  Fuel Cost/Year           35952 non-null  int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 4.1+ MB

# %% [markdown]
# ##Q1. What is the average CO2 emmission per gram/mile of all Volkswagen cars?
#
# ##### Format: A floating number
# ##### Example answer:
#  `11.547`

# %%
########## Q1
#Your code here
df[df['Make'] == 'Volkswagen']['CO2 Emission Grams/Mile'].mean()
#df.Make.unique()
#Example answer:
answer_dict["Q1"] =  df[df['Make'] == 'Volkswagen']['CO2 Emission Grams/Mile'].mean()
# Out:
# 392.7417210857633

# %% [markdown]
# ##Q2. Calculate the top 5 brands(Make) with the most unique models, order your answer in descending order with respect to the number of unique models.
# ##### **NOTE:** Consider only the name of the models and their brand, that is use only the Make and Model columns
# ##### Format: A 5X2 list with each row being the name of the brand followed by the unique number of models, in descending order.
# #####Hint: You can use the pandas [df.values.tolist()](https://pandas.pydata.org/docs/reference/api/pandas.Series.tolist.html) function to format your answer.
#
# ##### Example answer:
# `[["Volkswagen", 1000], ["Toyota", 900], ["Honda", 800], ["Subaru", 700], ["Ford", 600]]`

# %%
########## Q2
#Your code here
print(df.shape)
df_top_brands= df[['Make', 'Model']]
df_top_brands.drop_duplicates(inplace=True)
print(df_top_brands.shape)
df_top_brands.head()
top_brands = df_top_brands.Make.value_counts()
top_brands_list = top_brands.values.tolist()
top_brands_list
#
#Example answer:
#answer_dict["Q2"] =  [["Volkswagen", 1000], ["Toyota", 900], ["Honda", 800], ["Subaru", 700], ["Ford", 600]]
# Out:
# (35952, 15)
# (3676, 2)
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# [['AM General', 'DJ Po Vehicle 2WD'],
#  ['AM General', 'FJ8c Post Office'],
#  ['AM General', 'Post Office DJ5 2WD'],
#  ['AM General', 'Post Office DJ8 2WD'],
#  ['ASC Incorporated', 'GNX'],
#  ['Acura', '2.2CL/3.0CL'],
#  ['Acura', '2.3CL/3.0CL'],
#  ['Acura', '2.5TL'],
#  ['Acura', '2.5TL/3.2TL'],
#  ['Acura', '3.2CL'],
#  ['Acura', '3.2TL'],
#  ['Acura', '3.5RL'],
#  ['Acura', 'ILX'],
#  ['Acura', 'ILX Hybrid'],
#  ['Acura', 'Integra'],
#  ['Acura', 'Legend'],
#  ['Acura', 'MDX'],
#  ['Acura', 'MDX 2WD'],
#  ['Acura', 'MDX 4WD'],
#  ['Acura', 'MDX AWD'],
#  ['Acura', 'MDX FWD'],
#  ['Acura', 'NSX'],
#  ['Acura', 'NSX Hybrid'],
#  ['Acura', 'RDX 2WD'],
#  ['Acura', 'RDX 4WD'],
#  ['Acura', 'RDX AWD'],
#  ['Acura', 'RDX FWD'],
#  ['Acura', 'RL'],
#  ['Acura', 'RLX'],
#  ['Acura', 'RLX Hybrid'],
#  ['Acura', 'RSX'],
#  ['Acura', 'SLX'],
#  ['Acura', 'TL'],
#  ['Acura', 'TL 2WD'],
#  ['Acura', 'TL 4WD'],
#  ['Acura', 'TLX'],
#  ['Acura', 'TLX 2WD'],
#  ['Acura', 'TLX 4WD'],
#  ['Acura', 'TLX AWD'],
#  ['Acura', 'TLX FWD'],
#  ['Acura', 'TSX'],
#  ['Acura', 'TSX Wagon'],
#  ['Acura', 'Vigor'],
#  ['Acura', 'ZDX 4WD'],
#  ['Alfa Romeo', '164'],
#  ['Alfa Romeo', '4C'],
#  ['Alfa Romeo', '8 C Spider'],
#  ['Alfa Romeo', 'GT V6 2.5'],
#  ['Alfa Romeo', 'GTV'],
#  ['Alfa Romeo', 'Milano'],
#  ['Alfa Romeo', 'Spider'],
#  ['Alfa Romeo', 'Spider Veloce 2000'],
#  ['American Motors Corporation', 'Eagle'],
#  ['American Motors Corporation', 'Eagle 4DR Wagon'],
#  ['American Motors Corporation', 'Eagle 4WD'],
#  ['American Motors Corporation', 'Eagle SX/4 4WD'],
#  ['Aston Martin', 'DB AR1'],
#  ['Aston Martin', 'DB-7 GT Coupe'],
#  ['Aston Martin', 'DB-7 GT Volante'],
#  ['Aston Martin', 'DB-7 Vantage Coupe'],
#  ['Aston Martin', 'DB-7 Vantage Volante'],
#  ['Aston Martin', 'DB7 Coupe'],
#  ['Aston Martin', 'DB7 Volante'],
#  ['Aston Martin', 'DB9'],
#  ['Aston Martin', 'DB9 Coupe'],
#  ['Aston Martin', 'DB9 Coupe Manual'],
#  ['Aston Martin', 'DB9 Volante'],
#  ['Aston Martin', 'DB9 Volante Manual'],
#  ['Aston Martin', 'DBS'],
#  ['Aston Martin', 'DBS Coupe'],
#  ['Aston Martin', 'Lagonda'],
#  ['Aston Martin', 'Rapide'],
#  ['Aston Martin', 'Rapide S'],
#  ['Aston Martin', 'Saloon/Vantage/Volante'],
#  ['Aston Martin', 'V12 Vanquish'],
#  ['Aston Martin', 'V12 Vanquish S'],
#  ['Aston Martin', 'V12 Vantage'],
#  ['Aston Martin', 'V12 Vantage S'],
#  ['Aston Martin', 'V8 Vantage'],
#  ['Aston Martin', 'V8 Vantage ASM'],
#  ['Aston Martin', 'V8 Vantage S'],
#  ['Aston Martin', 'Vanquish'],
#  ['Aston Martin', 'Vantage GT'],
#  ['Aston Martin', 'Virage'],
#  ['Aston Martin', 'Virage Saloon'],
#  ['Aston Martin', 'Virage/Volante'],
#  ['Audi', '100'],
#  ['Audi', '100 Wagon'],
#  ['Audi', '100 quattro'],
#  ['Audi', '100 quattro Wagon'],
#  ['Audi', '200'],
#  ['Audi', '200 quattro'],
#  ['Audi', '200 quattro 20v'],
#  ['Audi', '200 quattro 20v Wagon'],
#  ['Audi', '200 quattro Wagon'],
#  ['Audi', '4000'],
#  ['Audi', '4000 CS quattro'],
#  ['Audi', '4000 S'],
#  ['Audi', '4000s'],
#  ['Audi', '4000s quattro'],
#  ['Audi', '5000 CS Turbo'],
#  ['Audi', '5000 CS quattro'],
#  ['Audi', '5000 CS quattro Wagon'],
#  ['Audi', '5000 S'],
#  ['Audi', '5000 S quattro'],
#  ['Audi', '5000S'],
#  ['Audi', '5000S Wagon'],
#  ['Audi', '80'],
#  ['Audi', '80 quattro'],
#  ['Audi', '80/90'],
#  ['Audi', '80/90 quattro'],
#  ['Audi', '90'],
#  ['Audi', '90 quattro'],
#  ['Audi', '90 quattro 20v'],
#  ['Audi', 'A3'],
#  ['Audi', 'A3 Cabriolet'],
#  ['Audi', 'A3 Cabriolet quattro'],
#  ['Audi', 'A3 e-tron'],
#  ['Audi', 'A3 e-tron ultra'],
#  ['Audi', 'A3 quattro'],
#  ['Audi', 'A4'],
#  ['Audi', 'A4 Avant'],
#  ['Audi', 'A4 Avant quattro'],
#  ['Audi', 'A4 Cabriolet'],
#  ['Audi', 'A4 Cabriolet quattro'],
#  ['Audi', 'A4 Ultra'],
#  ['Audi', 'A4 allroad quattro'],
#  ['Audi', 'A4 quattro'],
#  ['Audi', 'A5 Cabriolet'],
#  ['Audi', 'A5 Cabriolet quattro'],
#  ['Audi', 'A5 quattro'],
#  ['Audi', 'A6'],
#  ['Audi', 'A6 Avant quattro'],
#  ['Audi', 'A6 Wagon'],
#  ['Audi', 'A6 Wagon quattro'],
#  ['Audi', 'A6 quattro'],
#  ['Audi', 'A6 quattro Wagon'],
#  ['Audi', 'A7 quattro'],
#  ['Audi', 'A8'],
#  ['Audi', 'A8 L'],
#  ['Audi', 'A8 quattro'],
#  ['Audi', 'Allroad'],
#  ['Audi', 'Allroad quattro'],
#  ['Audi', 'Cabriolet'],
#  ['Audi', 'Coupe GT'],
#  ['Audi', 'Coupe quattro'],
#  ['Audi', 'Q3'],
#  ['Audi', 'Q3 quattro'],
#  ['Audi', 'Q5'],
#  ['Audi', 'Q5 Hybrid'],
#  ['Audi', 'Q7'],
#  ['Audi', 'Quattro'],
#  ['Audi', 'R8'],
#  ['Audi', 'R8 Spyder'],
#  ['Audi', 'RS 5'],
#  ['Audi', 'RS 5 Cabriolet'],
#  ['Audi', 'RS 7'],
#  ['Audi', 'RS4'],
#  ['Audi', 'RS4 Cabriolet'],
#  ['Audi', 'RS6'],
#  ['Audi', 'S3'],
#  ['Audi', 'S4'],
#  ['Audi', 'S4 Avant'],
#  ['Audi', 'S4 Cabriolet'],
#  ['Audi', 'S5'],
#  ['Audi', 'S5 Cabriolet'],
#  ['Audi', 'S6'],
#  ['Audi', 'S6 Avant'],
#  ['Audi', 'S6 Wagon'],
#  ['Audi', 'S7'],
#  ['Audi', 'S8'],
#  ['Audi', 'S8 quattro'],
#  ['Audi', 'SQ5'],
#  ['Audi', 'TT Coupe'],
#  ['Audi', 'TT Coupe quattro'],
#  ['Audi', 'TT RS Coupe'],
#  ['Audi', 'TT Roadster'],
#  ['Audi', 'TT Roadster quattro'],
#  ['Audi', 'TTS Coupe'],
#  ['Audi', 'V8'],
#  ['Audi', 'allroad quattro'],
#  ['Aurora Cars Ltd', 'Aurora'],
#  ['Autokraft Limited', 'A.C.MARK IV'],
#  ['Autokraft Limited', 'A.C.Mkiv'],
#  ['BMW', '128ci Convertible'],
#  ['BMW', '128i'],
#  ['BMW', '128i Convertible'],
#  ['BMW', '135i'],
#  ['BMW', '135i Convertible'],
#  ['BMW', '228i'],
#  ['BMW', '228i Convertible'],
#  ['BMW', '228i xDrive'],
#  ['BMW', '228i xDrive Convertible'],
#  ['BMW', '230i Convertible'],
#  ['BMW', '230i Coupe'],
#  ['BMW', '230i xDrive Convertible'],
#  ['BMW', '230i xDrive Coupe'],
#  ['BMW', '3 Series'],
#  ['BMW', '318i'],
#  ['BMW', '318i Convertible'],
#  ['BMW', '318i/318iS'],
#  ['BMW', '318i/318is'],
#  ['BMW', '318is'],
#  ['BMW', '318is Convertible'],
#  ['BMW', '318ti'],
#  ['BMW', '320i'],
#  ['BMW', '320i xDrive'],
#  ['BMW', '323ci'],
#  ['BMW', '323i'],
#  ['BMW', '323i Convertible'],
#  ['BMW', '323i Touring'],
#  ['BMW', '323is'],
#  ['BMW', '325ci'],
#  ['BMW', '325ci Convertible'],
#  ['BMW', '325i'],
#  ['BMW', '325i Convertible'],
#  ['BMW', '325i Sport Wagon'],
#  ['BMW', '325i/325iS'],
#  ['BMW', '325i/325is'],
#  ['BMW', '325ic'],
#  ['BMW', '325is'],
#  ['BMW', '325ix'],
#  ['BMW', '325xi'],
#  ['BMW', '325xi Sport Wagon'],
#  ['BMW', '328ci'],
#  ['BMW', '328ci Convertible'],
#  ['BMW', '328ci xDrive'],
#  ['BMW', '328cxi'],
#  ['BMW', '328d'],
#  ['BMW', '328d xDrive'],
#  ['BMW', '328d xDrive Sports Wagon'],
#  ['BMW', '328i'],
#  ['BMW', '328i Convertible'],
#  ['BMW', '328i Coupe'],
#  ['BMW', '328i Coupe xDrive'],
#  ['BMW', '328i Sport Wagon'],
#  ['BMW', '328i Sport Wagon xDrive'],
#  ['BMW', '328i Sports Wagon'],
#  ['BMW', '328i xDrive'],
#  ['BMW', '328i xDrive Gran Turismo'],
#  ['BMW', '328i xDrive Sport Wagon'],
#  ['BMW', '328i xDrive Sports Wagon'],
#  ['BMW', '328i/328is'],
#  ['BMW', '328ic'],
#  ['BMW', '328is'],
#  ['BMW', '328xi'],
#  ['BMW', '328xi Sport Wagon'],
#  ['BMW', '330ci'],
#  ['BMW', '330ci Convertible'],
#  ['BMW', '330e'],
#  ['BMW', '330i'],
#  ['BMW', '330i xDrive'],
#  ['BMW', '330i xDrive Gran Turismo'],
#  ['BMW', '330i xDrive Sports Wagon'],
#  ['BMW', '330xi'],
#  ['BMW', '335ci'],
#  ['BMW', '335ci Convertible'],
#  ['BMW', '335ci xDrive'],
#  ['BMW', '335cxi'],
#  ['BMW', '335d'],
#  ['BMW', '335i'],
#  ['BMW', '335i Convertible'],
#  ['BMW', '335i Coupe'],
#  ['BMW', '335i Coupe xDrive'],
#  ['BMW', '335i xDrive'],
#  ['BMW', '335i xDrive Gran Turismo'],
#  ['BMW', '335is Convertible'],
#  ['BMW', '335is Coupe'],
#  ['BMW', '335xi'],
#  ['BMW', '340i'],
#  ['BMW', '340i xDrive'],
#  ['BMW', '340i xDrive Gran Turismo'],
#  ['BMW', '428i Convertible'],
#  ['BMW', '428i Coupe'],
#  ['BMW', '428i Gran Coupe'],
#  ['BMW', '428i xDrive Convertible'],
#  ['BMW', '428i xDrive Coupe'],
#  ['BMW', '428i xDrive Gran Coupe'],
#  ['BMW', '430i Convertible'],
#  ['BMW', '430i Coupe'],
#  ['BMW', '430i Gran Coupe'],
#  ['BMW', '430i xDrive Convertible'],
#  ['BMW', '430i xDrive Coupe'],
#  ['BMW', '430i xDrive Gran Coupe'],
#  ['BMW', '435i Convertible'],
#  ['BMW', '435i Coupe'],
#  ['BMW', '435i Gran Coupe'],
#  ['BMW', '435i xDrive Convertible'],
#  ['BMW', '435i xDrive Coupe'],
#  ['BMW', '435i xDrive Gran Coupe'],
#  ['BMW', '440i Convertible'],
#  ['BMW', '440i Coupe'],
#  ['BMW', '440i Gran Coupe'],
#  ['BMW', '440i xDrive Convertible'],
#  ['BMW', '440i xDrive Coupe'],
#  ['BMW', '440i xDrive Gran Coupe'],
#  ['BMW', '5 Series'],
#  ['BMW', '525i'],
#  ['BMW', '525i Sport Wagon'],
#  ['BMW', '525i Touring'],
#  ['BMW', '525xi'],
#  ['BMW', '528i'],
#  ['BMW', '528i Sport Wagon'],
#  ['BMW', '528i Touring'],
#  ['BMW', '528i xDrive'],
#  ['BMW', '528xi'],
#  ['BMW', '530i'],
#  ['BMW', '530i Touring'],
#  ['BMW', '530xi'],
#  ['BMW', '530xi Sport Wagon'],
#  ['BMW', '535d'],
#  ['BMW', '535d xDrive'],
#  ['BMW', '535i'],
#  ['BMW', '535i Gran Turismo'],
#  ['BMW', '535i Sport Wagon xDrive'],
#  ['BMW', '535i xDrive'],
#  ['BMW', '535i xDrive Gran Turismo'],
#  ['BMW', '535xi'],
#  ['BMW', '535xi Sport Wagon'],
#  ['BMW', '540i'],
#  ['BMW', '540i Sport Wagon'],
#  ['BMW', '540i Touring'],
#  ['BMW', '545i'],
#  ['BMW', '550 GT'],
#  ['BMW', '550i'],
#  ['BMW', '550i Gran Turismo'],
#  ['BMW', '550i xDrive'],
#  ['BMW', '550i xDrive GT'],
#  ['BMW', '550i xDrive Gran Turismo'],
#  ['BMW', '6 Series'],
#  ['BMW', '635csi'],
#  ['BMW', '640i Convertible'],
#  ['BMW', '640i Coupe'],
#  ['BMW', '640i Gran Coupe'],
#  ['BMW', '640i xDrive Convertible'],
#  ['BMW', '640i xDrive Coupe'],
#  ['BMW', '640i xDrive Gran Coupe'],
#  ['BMW', '645ci'],
#  ['BMW', '645ci Convertible'],
#  ['BMW', '650ci'],
#  ['BMW', '650ci Convertible'],
#  ['BMW', '650i Convertible'],
#  ['BMW', '650i Convertible xDrive'],
#  ['BMW', '650i Coupe'],
#  ['BMW', '650i Coupe xDrive'],
#  ['BMW', '650i Gran Coupe'],
#  ['BMW', '650i xDrive Convertible'],
#  ['BMW', '650i xDrive Coupe'],
#  ['BMW', '650i xDrive Gran Coupe'],
#  ['BMW', '7 Series'],
#  ['BMW', '735i'],
#  ['BMW', '735i Luxury'],
#  ['BMW', '735il'],
#  ['BMW', '740Ld xDrive'],
#  ['BMW', '740Li'],
#  ['BMW', '740Li xDrive'],
#  ['BMW', '740e xDrive'],
#  ['BMW', '740i'],
#  ['BMW', '740i xDrive'],
#  ['BMW', '740i/740i Sport'],
#  ['BMW', '740il'],
#  ['BMW', '740il/740il Protection'],
#  ['BMW', '745i'],
#  ['BMW', '745li'],
#  ['BMW', '750 Series'],
#  ['BMW', '750Li'],
#  ['BMW', '750Li xDrive'],
#  ['BMW', '750i'],
#  ['BMW', '750i xDrive'],
#  ['BMW', '750il'],
#  ['BMW', '750il/750il Protection'],
#  ['BMW', '750li'],
#  ['BMW', '760Li'],
#  ['BMW', '760i'],
#  ['BMW', '760li'],
#  ['BMW', '840ci'],
#  ['BMW', '850ci'],
#  ['BMW', '850csi'],
#  ['BMW', '850i'],
#  ['BMW', 'ActiveHybrid 3'],
#  ['BMW', 'ActiveHybrid 5'],
#  ['BMW', 'ActiveHybrid 7'],
#  ['BMW', 'ActiveHybrid 7L'],
#  ['BMW', 'ActiveHybrid 7Li'],
#  ['BMW', 'ActiveHybrid 7i'],
#  ['BMW', 'ActiveHybrid X6'],
#  ['BMW', 'Alpina B6 Gran Coupe xDrive'],
#  ['BMW', 'Alpina B6 xDrive Gran Coupe'],
#  ['BMW', 'Alpina B7 LWB'],
#  ['BMW', 'Alpina B7 LWB xDrive'],
#  ['BMW', 'Alpina B7 SWB'],
#  ['BMW', 'Alpina B7 SWB xDrive'],
#  ['BMW', 'Alpina B7 xDrive'],
#  ['BMW', 'M Coupe'],
#  ['BMW', 'M Roadster'],
#  ['BMW', 'M1 Coupe'],
#  ['BMW', 'M2'],
#  ['BMW', 'M235i'],
#  ['BMW', 'M235i Convertible'],
#  ['BMW', 'M235i xDrive'],
#  ['BMW', 'M235i xDrive Convertible'],
#  ['BMW', 'M240i Convertible'],
#  ['BMW', 'M240i Coupe'],
#  ['BMW', 'M240i xDrive Convertible'],
#  ['BMW', 'M240i xDrive Coupe'],
#  ['BMW', 'M3'],
#  ['BMW', 'M3 Convertible'],
#  ['BMW', 'M3 Coupe'],
#  ['BMW', 'M3 Sedan'],
#  ['BMW', 'M4 Convertible'],
#  ['BMW', 'M4 Coupe'],
#  ['BMW', 'M4 GTS'],
#  ['BMW', 'M5'],
#  ['BMW', 'M6'],
#  ['BMW', 'M6 Convertible'],
#  ['BMW', 'M6 Coupe'],
#  ['BMW', 'M6 Gran Coupe'],
#  ['BMW', 'X1 sDrive28i'],
#  ['BMW', 'X1 xDrive28i'],
#  ['BMW', 'X1 xDrive35i'],
#  ['BMW', 'X3'],
#  ['BMW', 'X3 3.0i'],
#  ['BMW', 'X3 3.0si'],
#  ['BMW', 'X3 sDrive 28i'],
#  ['BMW', 'X3 sDrive28i'],
#  ['BMW', 'X3 xDrive28d'],
#  ['BMW', 'X3 xDrive28i'],
#  ['BMW', 'X3 xDrive30i'],
#  ['BMW', 'X3 xDrive35i'],
#  ['BMW', 'X4 M40i'],
#  ['BMW', 'X4 xDrive28i'],
#  ['BMW', 'X4 xDrive35i'],
#  ['BMW', 'X5'],
#  ['BMW', 'X5 3.0si'],
#  ['BMW', 'X5 4.6is'],
#  ['BMW', 'X5 4.8IS'],
#  ['BMW', 'X5 4.8i'],
#  ['BMW', 'X5 4.8is'],
#  ['BMW', 'X5 M'],
#  ['BMW', 'X5 sDrive35i'],
#  ['BMW', 'X5 xDrive30i'],
#  ['BMW', 'X5 xDrive35d'],
#  ['BMW', 'X5 xDrive35i'],
#  ['BMW', 'X5 xDrive40e'],
#  ['BMW', 'X5 xDrive48i'],
#  ['BMW', 'X5 xDrive50i'],
#  ['BMW', 'X5 xDriveM'],
#  ['BMW', 'X6 M'],
#  ['BMW', 'X6 sDrive35i'],
#  ['BMW', 'X6 xDrive35i'],
#  ['BMW', 'X6 xDrive50i'],
#  ['BMW', 'X6 xDriveM'],
#  ['BMW', 'Z3 Coupe'],
#  ['BMW', 'Z3 Roadster'],
#  ['BMW', 'Z4 3.0i'],
#  ['BMW', 'Z4 3.0si'],
#  ['BMW', 'Z4 3.0si Coupe'],
#  ['BMW', 'Z4 Coupe'],
#  ['BMW', 'Z4 M Coupe'],
#  ['BMW', 'Z4 M Roadster'],
#  ['BMW', 'Z4 Roadster'],
#  ['BMW', 'Z4 sDrive28i'],
#  ['BMW', 'Z4 sDrive30i'],
#  ['BMW', 'Z4 sDrive35i'],
#  ['BMW', 'Z4 sDrive35is'],
#  ['BMW', 'Z8'],
#  ['BMW', 'i3 REX'],
#  ['BMW', 'i8'],
#  ['BMW Alpina', 'B7'],
#  ['BMW Alpina', 'Roadster V8'],
#  ['Bentley', 'Arnage'],
#  ['Bentley', 'Arnage LWB'],
#  ['Bentley', 'Arnage RL'],
#  ['Bentley', 'Azure'],
#  ['Bentley', 'Bentayga'],
#  ['Bentley', 'Brooklands'],
#  ['Bentley', 'Brooklands R'],
#  ['Bentley', 'Brooklands R Limo'],
#  ['Bentley', 'Continental Flying Spur'],
#  ['Bentley', 'Continental GT'],
#  ['Bentley', 'Continental GT Convertible'],
#  ['Bentley', 'Continental GT Speed Convertible'],
#  ['Bentley', 'Continental GT3-R'],
#  ['Bentley', 'Continental GTC'],
#  ['Bentley', 'Continental R'],
#  ['Bentley', 'Continental SC'],
#  ['Bentley', 'Continental Supersports'],
#  ['Bentley', 'Continental Supersports Convertible'],
#  ['Bentley', 'Continental T'],
#  ['Bentley', 'Flying Spur'],
#  ['Bentley', 'Mulsanne'],
#  ['Bentley', 'Turbo RT'],
#  ['Bertone', 'X1/9'],
#  ['Bill Dovell Motor Car Company', 'Dovell 230CE'],
#  ['Bill Dovell Motor Car Company', 'Dovell 230E'],
#  ['Bitter Gmbh and Co. Kg', 'Bitter SC'],
#  ['Bugatti', 'Veyron'],
#  ['Buick', 'Cascada'],
#  ['Buick', 'Century'],
#  ['Buick', 'Century Wagon'],
#  ['Buick', 'Coachbuilder Wagon'],
#  ['Buick', 'Electra/Park Avenue'],
#  ['Buick', 'Enclave AWD'],
#  ['Buick', 'Enclave FWD'],
#  ['Buick', 'Encore'],
#  ['Buick', 'Encore AWD'],
#  ['Buick', 'Envision AWD'],
#  ['Buick', 'Envision FWD'],
#  ['Buick', 'Estate Wagon'],
#  ['Buick', 'Funeral Coach/Hearse'],
#  ['Buick', 'LaCrosse'],
#  ['Buick', 'LaCrosse AWD'],
#  ['Buick', 'LaCrosse eAssist'],
#  ['Buick', 'Lacrosse/Allure'],
#  ['Buick', 'Lacrosse/Allure AWD'],
#  ['Buick', 'LeSabre'],
#  ['Buick', 'LeSabre/Electra Wagon'],
#  ['Buick', 'Lucerne'],
#  ['Buick', 'Lucerne FFV'],
#  ['Buick', 'Park Avenue'],
#  ['Buick', 'Rainier 2WD'],
#  ['Buick', 'Rainier AWD'],
#  ['Buick', 'Reatta'],
#  ['Buick', 'Regal'],
#  ['Buick', 'Regal AWD'],
#  ['Buick', 'Regal eAssist'],
#  ['Buick', 'Regal/Century'],
#  ['Buick', 'Rendezvous AWD'],
#  ['Buick', 'Rendezvous FWD'],
#  ['Buick', 'Riviera'],
#  ['Buick', 'Riviera Convertible'],
#  ['Buick', 'Roadmaster'],
#  ['Buick', 'Roadmaster Wagon'],
#  ['Buick', 'Skyhawk'],
#  ['Buick', 'Skyhawk Wagon'],
#  ['Buick', 'Skylark'],
#  ['Buick', 'Somerset Regal'],
#  ['Buick', 'Somerset/Skylark'],
#  ['Buick', 'Terraza AWD'],
#  ['Buick', 'Terraza FWD'],
#  ['Buick', 'Verano'],
#  ['CCC Engineering', 'Duntov GT'],
#  ['CX Automotive', 'CX 25 GTI'],
#  ['CX Automotive', 'CX 25 Prestige'],
#  ['CX Automotive', 'CX 25Tri'],
#  ['CX Automotive', 'Cxestate'],
#  ['CX Automotive', 'XM v6'],
#  ['CX Automotive', 'XM v6 Break'],
#  ['CX Automotive', 'XM v6a'],
#  ['Cadillac', 'ATS'],
#  ['Cadillac', 'ATS AWD'],
#  ['Cadillac', 'ATS-V'],
#  ['Cadillac', 'Allante'],
#  ['Cadillac', 'Armored DTS'],
#  ['Cadillac', 'Armored Deville'],
#  ['Cadillac', 'Brougham'],
#  ['Cadillac', 'Brougham/DeVille (RWD)'],
#  ['Cadillac', 'CT6'],
#  ['Cadillac', 'CT6 AWD'],
#  ['Cadillac', 'CTS'],
#  ['Cadillac', 'CTS AWD'],
#  ['Cadillac', 'CTS Sedan'],
#  ['Cadillac', 'CTS Sedan AWD'],
#  ['Cadillac', 'CTS V'],
#  ['Cadillac', 'CTS Wagon'],
#  ['Cadillac', 'CTS Wagon AWD'],
#  ['Cadillac', 'CTS-V'],
#  ['Cadillac', 'Catera'],
#  ['Cadillac', 'Cimarron'],
#  ['Cadillac', 'Commercial Chassis'],
#  ['Cadillac', 'DTS'],
#  ['Cadillac', 'DeVille'],
#  ['Cadillac', 'DeVille/60 Special'],
#  ['Cadillac', 'DeVille/Concourse'],
#  ['Cadillac', 'ELR'],
#  ['Cadillac', 'ELR Sport'],
#  ['Cadillac', 'Eldorado'],
#  ['Cadillac', 'Eldorado Convertible'],
#  ['Cadillac', 'Escalade 2WD'],
#  ['Cadillac', 'Escalade 2WD FFV'],
#  ['Cadillac', 'Escalade 4WD'],
#  ['Cadillac', 'Escalade AWD'],
#  ['Cadillac', 'Escalade AWD FFV'],
#  ['Cadillac', 'Escalade ESV 2WD'],
#  ['Cadillac', 'Escalade ESV 2WD FFV'],
#  ['Cadillac', 'Escalade ESV 4WD'],
#  ['Cadillac', 'Escalade ESV AWD'],
#  ['Cadillac', 'Escalade Ext AWD'],
#  ['Cadillac', 'Escalade Hybrid 2WD'],
#  ['Cadillac', 'Escalade Hybrid 4WD'],
#  ['Cadillac', 'Fleetwood'],
#  ['Cadillac', 'Fleetwood Brougham'],
#  ['Cadillac', 'Fleetwood Brougham (RWD)'],
#  ['Cadillac', 'Fleetwood/DeVille'],
#  ['Cadillac', 'Fleetwood/DeVille (FWD)'],
#  ['Cadillac', 'Funeral Coach / Hearse'],
#  ['Cadillac', 'Funeral Coach/Hearse'],
#  ['Cadillac', 'Limousine'],
#  ['Cadillac', 'SRX'],
#  ['Cadillac', 'SRX 2WD'],
#  ['Cadillac', 'SRX AWD'],
#  ['Cadillac', 'STS'],
#  ['Cadillac', 'STS 2WD'],
#  ['Cadillac', 'STS AWD'],
#  ['Cadillac', 'STS-V'],
#  ['Cadillac', 'Seville'],
#  ['Cadillac', 'XLR'],
#  ['Cadillac', 'XLR-V'],
#  ['Cadillac', 'XT5'],
#  ['Cadillac', 'XT5 AWD'],
#  ['Cadillac', 'XTS'],
#  ['Cadillac', 'XTS AWD'],
#  ['Cadillac', 'XTS Hearse'],
#  ['Cadillac', 'XTS LIMO'],
#  ['Cadillac', 'XTS Limo'],
#  ['Chevrolet', 'Astro 2WD (cargo)'],
#  ['Chevrolet', 'Astro 2WD (cargo) Conversion'],
#  ['Chevrolet', 'Astro 2WD (passenger)'],
#  ['Chevrolet', 'Astro AWD (cargo)'],
#  ['Chevrolet', 'Astro AWD (cargo) Conversion'],
#  ['Chevrolet', 'Astro AWD (passenger)'],
#  ['Chevrolet', 'Avalanche 1500 2WD'],
#  ['Chevrolet', 'Avalanche 1500 2WD FFV'],
#  ['Chevrolet', 'Avalanche 1500 4WD'],
#  ['Chevrolet', 'Avalanche 1500 AWD'],
#  ['Chevrolet', 'Aveo'],
#  ['Chevrolet', 'Aveo 5'],
#  ['Chevrolet', 'Beretta'],
#  ['Chevrolet', 'Blazer 1500 4WD'],
#  ['Chevrolet', 'Blazer 2WD'],
#  ['Chevrolet', 'Blazer 4WD'],
#  ['Chevrolet', 'Blazer AWD'],
#  ['Chevrolet', 'Blazer V1500 4WD'],
#  ['Chevrolet', 'C10 Pickup 2WD'],
#  ['Chevrolet', 'C1500 Pickup 2WD'],
#  ['Chevrolet', 'C20 Pickup 2WD'],
#  ['Chevrolet', 'C2500 Pickup 2WD'],
#  ['Chevrolet', 'Camaro'],
#  ['Chevrolet', 'Caprice'],
#  ['Chevrolet', 'Caprice Wagon'],
#  ['Chevrolet', 'Caprice/Impala'],
#  ['Chevrolet', 'Caprice/Impala Wagon'],
#  ['Chevrolet', 'Captiva AWD'],
#  ['Chevrolet', 'Captiva FWD'],
#  ['Chevrolet', 'Cavalier'],
#  ['Chevrolet', 'Cavalier (Bi-fuel CNG)'],
#  ['Chevrolet', 'Cavalier Convertible'],
#  ['Chevrolet', 'Cavalier Dual-fuel'],
#  ['Chevrolet', 'Cavalier Wagon'],
#  ['Chevrolet', 'Celebrity'],
#  ['Chevrolet', 'Celebrity Wagon'],
#  ['Chevrolet', 'Chevette'],
#  ['Chevrolet', 'Chevette CS'],
#  ['Chevrolet', 'Citation II'],
#  ['Chevrolet', 'City Express Cargo Van'],
#  ['Chevrolet', 'Classic'],
#  ['Chevrolet', 'Coachbuilder Wagon'],
#  ['Chevrolet', 'Cobalt'],
#  ['Chevrolet', 'Cobalt Coupe'],
#  ['Chevrolet', 'Cobalt SS Coupe'],
#  ['Chevrolet', 'Cobalt Sedan'],
#  ['Chevrolet', 'Cobalt XFE'],
#  ['Chevrolet', 'Cobalt XFE Coupe'],
#  ['Chevrolet', 'Cobalt XFE Sedan'],
#  ['Chevrolet', 'Colorado 2WD'],
#  ['Chevrolet', 'Colorado 4WD'],
#  ['Chevrolet', 'Colorado Cab Chassis 2WD'],
#  ['Chevrolet', 'Colorado Cab Chassis inc 2WD'],
#  ['Chevrolet', 'Colorado Cab Chassis inc 4WD'],
#  ['Chevrolet', 'Colorado Crew Cab 2WD'],
#  ['Chevrolet', 'Colorado Crew Cab 4WD'],
#  ['Chevrolet', 'Corsica'],
#  ['Chevrolet', 'Corvette'],
#  ['Chevrolet', 'Corvette Convertible'],
#  ['Chevrolet', 'Cruze'],
#  ['Chevrolet', 'Cruze Eco'],
#  ['Chevrolet', 'Cruze Hatchback'],
#  ['Chevrolet', 'Cruze Limited'],
#  ['Chevrolet', 'Cruze Limited  Eco'],
#  ['Chevrolet', 'Cruze Premier'],
#  ['Chevrolet', 'Cruze Premier Hatchback'],
#  ['Chevrolet', 'El Camino Pickup 2WD'],
#  ['Chevrolet', 'Epica'],
#  ['Chevrolet', 'Equinox AWD'],
#  ['Chevrolet', 'Equinox FWD'],
#  ['Chevrolet', 'Express 1500 2WD Cargo'],
#  ['Chevrolet', 'Express 1500 2WD Cargo FFV'],
#  ['Chevrolet', 'Express 1500 2WD Conversion Cargo'],
#  ['Chevrolet', 'Express 1500 2WD Conversion Cargo FFV'],
#  ['Chevrolet', 'Express 1500 2WD Passenger'],
#  ['Chevrolet', 'Express 1500 2WD Passenger FFV'],
#  ['Chevrolet', 'Express 1500 AWD'],
#  ['Chevrolet', 'Express 1500 AWD Cargo'],
#  ['Chevrolet', 'Express 1500 AWD Cargo FFV'],
#  ['Chevrolet', 'Express 1500 AWD Conversion Cargo'],
#  ['Chevrolet', 'Express 1500 AWD Conversion Cargo FFV'],
#  ['Chevrolet', 'Express 1500 AWD Passenger'],
#  ['Chevrolet', 'Express 1500 AWD Passenger FFV'],
#  ['Chevrolet', 'Express 1500/2500 2WD'],
#  ['Chevrolet', 'Express 2500 2WD Cargo'],
#  ['Chevrolet', 'Express 2500 2WD Conversion Cargo'],
#  ['Chevrolet', 'Express 2500 2WD Passenger'],
#  ['Chevrolet', 'Express 3500 2WD Cargo'],
#  ['Chevrolet', 'Express 3500 2WD Passenger'],
#  ['Chevrolet', 'Express Cargo (Bi-fuel)'],
#  ['Chevrolet', 'Express Cargo (dedicated CNG)'],
#  ['Chevrolet', 'Express Passenger (Bi-fuel)'],
#  ['Chevrolet', 'Express Passenger (dedicated CNG)'],
#  ['Chevrolet', 'G10/20 Sport Van 2WD'],
#  ['Chevrolet', 'G10/20 Van 2WD'],
#  ['Chevrolet', 'G10/20 Van 2WD (cargo)'],
#  ['Chevrolet', 'G30 Sport Van 2WD'],
#  ['Chevrolet', 'G30 Van 2WD'],
#  ['Chevrolet', 'G30 Van 2WD (cargo)'],
#  ['Chevrolet', 'HHR FWD'],
#  ['Chevrolet', 'HHR FWD FFV'],
#  ['Chevrolet', 'HHR Panel FWD'],
#  ['Chevrolet', 'HHR Panel FWD FFV'],
#  ['Chevrolet', 'Impala'],
#  ['Chevrolet', 'Impala Bi-Fuel  (CNG)'],
#  ['Chevrolet', 'Impala FFV'],
#  ['Chevrolet', 'Impala Limited'],
#  ['Chevrolet', 'Impala Police'],
#  ['Chevrolet', 'Impala eAssist'],
#  ['Chevrolet', 'Impala/Caprice'],
#  ['Chevrolet', 'K10 Blazer 4WD'],
#  ['Chevrolet', 'K10 Pickup 4WD'],
#  ['Chevrolet', 'K1500 Pickup 4WD'],
#  ['Chevrolet', 'K20 Pickup 4WD'],
#  ['Chevrolet', 'K2500 Pickup 4WD'],
#  ['Chevrolet', 'K5/K10 Blazer 4WD'],
#  ['Chevrolet', 'Lumina'],
#  ['Chevrolet', 'Lumina Minivan 2WD'],
#  ['Chevrolet', 'Lumina/APV Minivan 2WD'],
#  ['Chevrolet', 'Lumina/Monte Carlo'],
#  ['Chevrolet', 'Malibu'],
#  ['Chevrolet', 'Malibu FFV'],
#  ['Chevrolet', 'Malibu Hybrid'],
#  ['Chevrolet', 'Malibu Limited'],
#  ['Chevrolet', 'Malibu Maxx'],
#  ['Chevrolet', 'Malibu eAssist'],
#  ['Chevrolet', 'Metro'],
#  ['Chevrolet', 'Monte Carlo'],
#  ['Chevrolet', 'Nova'],
#  ['Chevrolet', 'Optra'],
#  ['Chevrolet', 'Optra 5'],
#  ['Chevrolet', 'Optra Wagon'],
#  ['Chevrolet', 'Pickup 2500 2WD'],
#  ['Chevrolet', 'Pickup 2500 4WD'],
#  ['Chevrolet', 'Postal Cab Chassis 2WD'],
#  ['Chevrolet', 'Prizm'],
#  ['Chevrolet', 'R10 Pickup 2WD'],
#  ['Chevrolet', 'R10 Suburban 2WD'],
#  ['Chevrolet', 'R1500 Suburban 2WD'],
#  ['Chevrolet', 'R20 (C20) Pickup 2WD'],
#  ['Chevrolet', 'S10 Blazer 2WD'],
#  ['Chevrolet', 'S10 Blazer 4WD'],
#  ['Chevrolet', 'S10 Cab Chassis 2WD'],
#  ['Chevrolet', 'S10 Pickup 2WD'],
#  ['Chevrolet', 'S10 Pickup 2WD FFV'],
#  ['Chevrolet', 'S10 Pickup 4WD'],
#  ['Chevrolet', 'S10 Utility Body 2WD'],
#  ['Chevrolet', 'SS'],
#  ['Chevrolet', 'SSR Pickup 2WD'],
#  ['Chevrolet', 'Silverado 15 Hybrid 2WD'],
#  ['Chevrolet', 'Silverado 15 Hybrid 4WD'],
#  ['Chevrolet', 'Silverado 1500 2WD'],
#  ['Chevrolet', 'Silverado 1500 4WD'],
#  ['Chevrolet', 'Silverado 1500 AWD'],
#  ['Chevrolet', 'Silverado 2500 2WD'],
#  ['Chevrolet', 'Silverado 2500 2WD (Bifuel)'],
#  ['Chevrolet', 'Silverado 2500 HD 2WD'],
#  ['Chevrolet', 'Silverado 2500 HD 2WD CNG'],
#  ['Chevrolet', 'Silverado 2500 HD 4WD CNG'],
#  ['Chevrolet', 'Silverado C15 2WD'],
#  ['Chevrolet', 'Silverado C15 2WD FFV'],
#  ['Chevrolet', 'Silverado C15 Cab Chassis 2WD'],
#  ['Chevrolet', 'Silverado C15 XFE 2WD'],
#  ['Chevrolet', 'Silverado C15 XFE 2WD FFV'],
#  ['Chevrolet', 'Silverado Classic 15 Hybrid 2WD'],
#  ['Chevrolet', 'Silverado Classic 15 Hybrid 4WD'],
#  ['Chevrolet', 'Silverado Classic 1500 2WD'],
#  ['Chevrolet', 'Silverado Classic 1500 4WD'],
#  ['Chevrolet', 'Silverado K15 4WD'],
#  ['Chevrolet', 'Silverado K15 4WD FFV'],
#  ['Chevrolet', 'Silverado K15 Cab Chassis 4WD'],
#  ['Chevrolet', 'Silverado SS 1500 AWD'],
#  ['Chevrolet', 'Sonic'],
#  ['Chevrolet', 'Sonic 5'],
#  ['Chevrolet', 'Sonic 5 RS'],
#  ['Chevrolet', 'Sonic RS'],
#  ['Chevrolet', 'Spark'],
#  ['Chevrolet', 'Spectrum'],
#  ['Chevrolet', 'Spectrum Turbo'],
#  ['Chevrolet', 'Sport Van G10/20 2WD'],
#  ['Chevrolet', 'Sport Van G10/20 2WD (passenger)'],
#  ['Chevrolet', 'Sport Van G30  2WD'],
#  ['Chevrolet', 'Sport Van G30 2WD'],
#  ['Chevrolet', 'Sport Van G30 2WD (cargo)'],
#  ['Chevrolet', 'Sprint'],
#  ['Chevrolet', 'Sprint ER'],
#  ['Chevrolet', 'Sprint Metro'],
#  ['Chevrolet', 'Sprint Plus'],
#  ['Chevrolet', 'Suburban 1500 2WD'],
#  ['Chevrolet', 'Suburban 1500 2WD FFV'],
#  ['Chevrolet', 'Suburban 1500 4WD'],
#  ['Chevrolet', 'Suburban 1500 AWD'],
#  ['Chevrolet', 'Suburban 2500 2WD'],
#  ['Chevrolet', 'Suburban 2500 4WD'],
#  ['Chevrolet', 'Suburban C10 2WD'],
#  ['Chevrolet', 'Suburban C1500 2WD'],
#  ['Chevrolet', 'Suburban K10 4WD'],
#  ['Chevrolet', 'Suburban K1500 4WD'],
#  ['Chevrolet', 'Suburban V1500 4WD'],
#  ['Chevrolet', 'T10 (S10) Blazer 4WD'],
#  ['Chevrolet', 'T10 (S10) Pickup 4WD'],
#  ['Chevrolet', 'Tahoe 1500 2WD'],
#  ['Chevrolet', 'Tahoe 1500 2WD FFV'],
#  ['Chevrolet', 'Tahoe 1500 4WD'],
#  ['Chevrolet', 'Tahoe 1500 4WD FFV'],
#  ['Chevrolet', 'Tahoe 1500 AWD'],
#  ['Chevrolet', 'Tahoe 1500 XFE 2WD'],
#  ['Chevrolet', 'Tahoe C10 2WD'],
#  ['Chevrolet', 'Tahoe C1500 2WD'],
#  ['Chevrolet', 'Tahoe Hybrid 2WD'],
#  ['Chevrolet', 'Tahoe Hybrid 4WD'],
#  ['Chevrolet', 'Tahoe K10 4WD'],
#  ['Chevrolet', 'Tahoe K1500 4WD'],
#  ['Chevrolet', 'Tracker 2WD Convertible'],
#  ['Chevrolet', 'Tracker 2WD Hardtop'],
#  ['Chevrolet', 'Tracker 4WD Convertible'],
#  ['Chevrolet', 'Tracker 4WD Hardtop'],
#  ['Chevrolet', 'Tracker LT 2WD'],
#  ['Chevrolet', 'Tracker LT 4WD'],
#  ['Chevrolet', 'Tracker ZR2 4WD'],
#  ['Chevrolet', 'Tracker ZR2 4WD Convertible'],
#  ['Chevrolet', 'TrailBlazer 2WD'],
#  ['Chevrolet', 'TrailBlazer 4WD'],
#  ['Chevrolet', 'TrailBlazer AWD'],
#  ['Chevrolet', 'TrailBlazer Ext 2WD'],
#  ['Chevrolet', 'TrailBlazer Ext 4WD'],
#  ['Chevrolet', 'Traverse AWD'],
#  ['Chevrolet', 'Traverse FWD'],
#  ['Chevrolet', 'Trax'],
#  ['Chevrolet', 'Trax AWD'],
#  ['Chevrolet', 'Turbo Sprint'],
#  ['Chevrolet', 'Twin-Turbo Corvette'],
#  ['Chevrolet', 'Uplander AWD'],
#  ['Chevrolet', 'Uplander FWD'],
#  ['Chevrolet', 'V10 (K10) Blazer 4WD'],
#  ['Chevrolet', 'V10 (K10) Pickup 4WD'],
#  ['Chevrolet', 'V10 (K10) Suburban 4WD'],
#  ['Chevrolet', 'V10 Blazer 4WD'],
#  ['Chevrolet', 'V10 Suburban 4WD'],
#  ['Chevrolet', 'V20 Pickup 4WD'],
#  ['Chevrolet', 'Van 15/25  2WD Conversion'],
#  ['Chevrolet', 'Van 15/25 2WD Conversion'],
#  ['Chevrolet', 'Van 1500 2WD Cargo'],
#  ['Chevrolet', 'Van 1500 2WD Conversion Cargo'],
#  ['Chevrolet', 'Van 1500 AWD Cargo'],
#  ['Chevrolet', 'Van 1500 AWD Conversion'],
#  ['Chevrolet', 'Van 1500 AWD Conversion Cargo'],
#  ['Chevrolet', 'Van 1500/2500 2WD'],
#  ['Chevrolet', 'Van 1500/2500 AWD'],
#  ['Chevrolet', 'Venture 2WD'],
#  ['Chevrolet', 'Venture AWD'],
#  ['Chevrolet', 'Venture FWD'],
#  ['Chevrolet', 'Volt'],
#  ['Chrysler', '200'],
#  ['Chrysler', '200 AWD'],
#  ['Chrysler', '200 Convertible'],
#  ['Chrysler', '300'],
#  ['Chrysler', '300 AWD'],
#  ['Chrysler', '300 M'],
#  ['Chrysler', '300 SRT8'],
#  ['Chrysler', '300/SRT-8'],
#  ['Chrysler', '300C AWD'],
#  ['Chrysler', '300C/SRT-8'],
#  ['Chrysler', '300M'],
#  ['Chrysler', 'Aspen 2WD'],
#  ['Chrysler', 'Aspen 4WD'],
#  ['Chrysler', 'Aspen HEV'],
#  ['Chrysler', 'Cirrus'],
#  ['Chrysler', 'Concorde'],
#  ['Chrysler', 'Concorde/LHS'],
#  ['Chrysler', 'Conquest'],
#  ['Chrysler', 'Crossfire'],
#  ['Chrysler', 'Crossfire Coupe'],
#  ['Chrysler', 'Crossfire Roadster'],
#  ['Chrysler', 'Executive Sedan/Limousine'],
#  ['Chrysler', 'Fifth Avenue/Imperial'],
#  ['Chrysler', 'Imperial/New Yorker Fifth Avenue'],
#  ['Chrysler', 'JX/JXI/Limited Convertible'],
#  ['Chrysler', 'LHS'],
#  ['Chrysler', 'Laser'],
#  ['Chrysler', 'Laser/Daytona'],
#  ['Chrysler', 'LeBaron'],
#  ['Chrysler', 'LeBaron Convertible'],
#  ['Chrysler', 'LeBaron GTS'],
#  ['Chrysler', 'LeBaron Landau'],
#  ['Chrysler', 'Limousine'],
#  ['Chrysler', 'New Yorker'],
#  ['Chrysler', 'New Yorker Fifth Avenue/Imperial'],
#  ['Chrysler', 'New Yorker Turbo'],
#  ['Chrysler', 'New Yorker/5th Avenue'],
#  ['Chrysler', 'New Yorker/LHS'],
#  ['Chrysler', 'Newport/Fifth Avenue'],
#  ['Chrysler', 'PT Cruiser'],
#  ['Chrysler', 'PT Cruiser Convertible'],
#  ['Chrysler', 'Pacifica'],
#  ['Chrysler', 'Pacifica 2WD'],
#  ['Chrysler', 'Pacifica AWD'],
#  ['Chrysler', 'Pacifica FWD'],
#  ['Chrysler', 'Prowler'],
#  ['Chrysler', 'QC Car'],
#  ['Chrysler', 'Sebring'],
#  ['Chrysler', 'Sebring 4 Door'],
#  ['Chrysler', 'Sebring AWD'],
#  ['Chrysler', 'Sebring Convertible'],
#  ['Chrysler', 'Sebring Convertible FFV'],
#  ['Chrysler', 'Sebring FFV'],
#  ['Chrysler', 'TC By'],
#  ['Chrysler', 'TC By Convertible'],
#  ['Chrysler', 'TC by Maserati'],
#  ['Chrysler', 'Town and Country'],
#  ['Chrysler', 'Town and Country 2WD'],
#  ['Chrysler', 'Town and Country 4WD'],
#  ['Chrysler', 'Town and Country AWD'],
#  ['Chrysler', 'Town and Country FFV'],
#  ['Chrysler', 'Town and Country Wagon'],
#  ['Chrysler', 'Town and Country/Voyager/Grand Voy. 2WD'],
#  ['Chrysler', 'Town and Country/Voyager/Grand Voy. AWD'],
#  ['Chrysler', 'Voyager/Town and Country 2WD'],
#  ['Consulier Industries Inc', 'Consulier GTP'],
#  ['Dabryan Coach Builders Inc', 'WB'],
#  ['Dacia', 'Coupe'],
#  ['Dacia', 'Sedan'],
#  ['Dacia', 'Station Wagon'],
#  ['Daewoo', 'Kalos'],
#  ['Daewoo', 'Lacetti'],
#  ['Daewoo', 'Lanos'],
#  ['Daewoo', 'Leganza'],
#  ['Daewoo', 'Magnus'],
#  ['Daewoo', 'Nubira'],
#  ['Daewoo', 'Nubira Station Wagon'],
#  ['Daewoo', 'Nubira Wagon'],
#  ['Daihatsu', 'Charade'],
#  ['Daihatsu', 'Charade E'],
#  ['Daihatsu', 'Rocky 4WD'],
#  ['Dodge', '600'],
#  ['Dodge', '600 Convertible'],
#  ['Dodge', 'AD100/AD150 Ramcharger 2WD'],
#  ['Dodge', 'AW100/AW150 Ramcharger 4WD'],
#  ['Dodge', 'Aries'],
#  ['Dodge', 'Aries Wagon'],
#  ['Dodge', 'Avenger'],
#  ['Dodge', 'Avenger AWD'],
#  ['Dodge', 'Avenger FFV'],
#  ['Dodge', 'B150/B250 Van 2WD'],
#  ['Dodge', 'B150/B250 Wagon 2WD'],
#  ['Dodge', 'B1500 Van 2WD'],
#  ['Dodge', 'B1500 Wagon 2WD'],
#  ['Dodge', 'B1500/B2500 Van 2WD'],
#  ['Dodge', 'B1500/B2500 Wagon 2WD'],
#  ['Dodge', 'B2500 Van 2WD'],
#  ['Dodge', 'B2500 Wagon 2WD'],
#  ['Dodge', 'B350 Van 2WD'],
#  ['Dodge', 'B350 Wagon 2WD'],
#  ['Dodge', 'B3500 Van 2WD'],
#  ['Dodge', 'B3500 Wagon 2WD'],
#  ['Dodge', 'CSX'],
#  ['Dodge', 'Caliber'],
#  ['Dodge', 'Caliber AWD'],
#  ['Dodge', 'Caravan C/V/Grand Caravan 2WD'],
#  ['Dodge', 'Caravan C/V/Grand Caravan 4WD'],
#  ['Dodge', 'Caravan/Grand Caravan 2WD'],
#  ['Dodge', 'Caravan/Grand Caravan 4WD'],
#  ['Dodge', 'Caravan/Grand Caravan AWD'],
#  ['Dodge', 'Caravan/Grand Caravan FWD'],
#  ['Dodge', 'Caravan/Grand Caravan/Ram Van 2WD'],
#  ['Dodge', 'Caravan/Ram Van 2WD'],
#  ['Dodge', 'Challenger'],
#  ['Dodge', 'Challenger SRT8'],
#  ['Dodge', 'Charger'],
#  ['Dodge', 'Charger AWD'],
#  ['Dodge', 'Charger GLH-S'],
#  ['Dodge', 'Charger SRT8'],
#  ['Dodge', 'Colt'],
#  ['Dodge', 'Colt Vista'],
#  ['Dodge', 'Colt Vista 4WD'],
#  ['Dodge', 'Colt Wagon'],
#  ['Dodge', 'Colt Wagon 4WD'],
#  ['Dodge', 'Conquest'],
#  ['Dodge', 'D100/D150 Pickup 2WD'],
#  ['Dodge', 'D250 Cab Chassis 2WD'],
#  ['Dodge', 'D250 Pickup 2WD'],
#  ['Dodge', 'D250 Pickup Cab Chassis 2WD'],
#  ['Dodge', 'Dakota Cab Chassis 2WD'],
#  ['Dodge', 'Dakota Pickup 2WD'],
#  ['Dodge', 'Dakota Pickup 2WD FFV'],
#  ...]

# %% [markdown]
# ##Q3. What are all the different types of fuels in the dataset sorted alphabetically?
# ##### Format: A list of strings sorted alphabetically.
# ##### Example Answer:
# `['Regular',
#  'Premium']`

# %%
########## Q3
#Your code here

#Example answer:
#answer_dict["Q3"] =  ['Regular', 'Premium']

# %% [markdown]
# ##Q4. Show the 9 Toyota cars with the most extreme Fuel Barrels/Year in abosolute terms within all Toyota cars. Show the car Model, Year and their Fuel Barrels/Year in standard deviation units([Z-score](https://fredclavel.org/2019/03/18/basics-standardization-and-the-z-score/)) **sorted** in descending order by their Fuel Barrels/Year in absolute terms first and then by year in descending order **BUT** without modifying the negative values (see example).
#
# ##### Format: A 9X3 list with each row containing the Model, Year and Fuel Barrels/Year in standard deviations units
#
# ##### Example answer:
# ```
# [['DJ Po Vehicle 2WD', 2004, -6.407431084026927],
#  ['FJ8c Post Office', 2003, -6.407431084026927],
#  ['Post Office DJ5 2WD', 2005, -6.391684618442447],
#  ['Sierra 2500 Hd 2WD', 2002, -6.391684618442447],
#  ['Camry CNG', 2012, 2.677633075759575],
#  ['Sierra 1500 4WD', 2005, 2.677633075759575],
#  ['Sierra 1500 4WD', 2001, 2.677633075759575],
#  ['V15 Suburban 4WD', 1988, 2.677633075759575],
#  ['V15 Suburban 4WD', 1987, 2.677633075759575]]
# ```
# #####Note that while the list is sorted by the Fuel Barrels/Year in absolute terms and in standard deviation units, the values are not modified. If the values are the same the rows are sorted by the year.

# %%
########## Q4
#Your code here

# %% [markdown]
# ##Q5. Calculate the changes in Combined MPG with their previous model of all Golf cars with Manual 5-spd transmission and Regular Fuel Type. Show the Year, the Combined MPG and the calculated difference of MPG in a list sorted by Year in ascending order.
#
# ##### Format: A 19X3 list, with the Year and Combined MPG being of type integer **and only the calculated difference is of type float**
# ##### **Note: The value for the first model should be 0.** It does not matter that there are gaps in the years, calculate with respect the previous model.
#
# #####Example answer:
#
#
#
# ```
# [[1986, 25, 0.0],
#  [1987, 25, 0.0],
#  [1988, 25, 0.0],
#  [1989, 25, 0.0],
#  [1990, 23, -2.0],
#  [1991, 23, 0.0],
#  [1992, 24, 1.0],
#  [1993, 25, 1.0],
#  [1994, 25, 0.0],
#  [1995, 25, 0.0],
#  [1996, 25, 0.0],
#  [1997, 25, 0.0],
#  [1998, 24, -1.0],
#  [1999, 25, 1.0],
#  [2000, 24, -1.0],
#  [2001, 24, 0.0],
#  [2002, 24, 0.0],
#  [2004, 24, 0.0],
#  [2006, 24, 0.0]]
# ```

# %%
########## Q5
#Your code here

# %% [markdown]
# ##Q6. What are the top 5 lowest CO2 Emission Grams/Mile emmisions of cars for each of the following brands: Toyota, Ford, Volkswagen, Nissan, Honda
#
# #####Format: A 5X6 list with the first element of each row being the Make of the cars and the following five values being floats sorted in ascending order. The Makes should appear in order listed in the question starting with Ford and ending with Volkswagen (see example).
#
# #####Example answer:
#
# ```
# [['Toyota', 100.0, 140.0, 140.0, 150.0, 150.0],
#  ['Ford',
#   100.025641025641,
#   200.677633075759575,
#   200.677633075759575,
#   200.677633075759575,
#   200.677633075759575],
#  ['Volkswagen', 139.0, 154.0, 166.5, 166.5, 166.5],
#  ['Nissan', 122.0, 122.0, 122.0, 122.0, 160.0],
#  ['Honda', 100.0, 100.0, 100.0, 100.0, 123.91684618442447]]
# ```

# %%
########## Q6
#Your code here

# %% [markdown]
# ##Q7. Form 7 groups of 5 years to calculated the median Combined MPG of each group. The first group is from 1984 to 1988, the second from 1989 to 1993 and so on. The last group will have years not appearing in the dataset.
#
# #####Note: The groups ranges are inclusive on both sides, the first group starts with 1984 and cars from 1984 are included in it.
# #####Format : A 7X2 list with the first element of each row being a tuple of two integers being the lower and uppper range of the year groups and the esecond element being the median Combined MPG of that group, a float number.
#
# #####Example answer:
#
#
# ```
# [[(1984, 1988), 11.0],
#  [(1989, 1993), 10.0],
#  [(1994, 1998), 10.0],
#  [(1999, 2003), 14.0],
#  [(2004, 2008), 13.0],
#  [(2009, 2013), 14.0],
#  [(2014, 2018), 15.0]]
# ```

# %%
########## Q7
#Your code here

# %% [markdown]
# ##Test your answers
#
# ##### We provide you some tests to make sure your answer dictionary is in the correct format using unittest.
# ##### These tests are not meant to be comprehensive, you should review all your answers carefully.

# %%
import unittest

class TestAnswers(unittest.TestCase):
    def test_if_dict(self):
        self.assertIsInstance(answer_dict, dict)

    def test_keys(self):
        self.assertEqual(list(answer_dict.keys()), ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7'])

    def test_answers_types(self):
        types_values = [type(k) for k in answer_dict.values()]
        answer_types = [float, list, list, list, list, list, list]
        self.assertEqual(types_values, answer_types)

    def test_Q1(self):
        self.assertEqual(type(answer_dict['Q1']), float)

    def test_Q2_dim(self):
        self.assertEqual(np.array(answer_dict['Q2']).shape, (5,2))

    def test_Q2_types(self):
        dtype1 = type(answer_dict['Q2'][0][0])
        dtype2 = type(answer_dict['Q2'][0][1])
        self.assertEqual([dtype1, dtype2], [str, int])

    def test_Q3_types(self):
        q3_types = set([type(item) for item in answer_dict['Q3']])
        self.assertEqual(q3_types, {str})

    def test_Q4_dim(self):
        self.assertEqual(np.array(answer_dict['Q4']).shape, (9,3))

    def test_Q4_types(self):
        dtype1 = type(answer_dict['Q4'][0][0])
        dtype2 = type(answer_dict['Q4'][0][1])
        dtype3 = type(answer_dict['Q4'][0][2])
        self.assertEqual([dtype1, dtype2, dtype3], [str, int, float])

    def test_Q5_dim(self):
        self.assertEqual(np.array(answer_dict['Q5']).shape, (19,3))

    def test_Q5_types(self):
        dtype1 = type(answer_dict['Q5'][0][0])
        dtype2 = type(answer_dict['Q5'][0][1])
        dtype3 = type(answer_dict['Q5'][0][2])
        self.assertEqual([dtype1, dtype2, dtype3], [int, int, float])

    def test_Q5_first_zero(self):
        self.assertEqual(answer_dict['Q5'][0][2], 0)


    def test_Q6_dim(self):
        self.assertEqual(np.array(answer_dict['Q6']).shape, (5,6))

    def test_Q5_types(self):
        dtype1 = type(answer_dict['Q6'][0][0])
        dtype2 = type(answer_dict['Q6'][0][1])
        dtype3 = type(answer_dict['Q6'][0][2])
        dtype4 = type(answer_dict['Q6'][0][3])
        dtype5 = type(answer_dict['Q6'][0][4])
        dtype6 = type(answer_dict['Q6'][0][5])
        self.assertEqual([dtype1, dtype2, dtype3, dtype4, dtype5, dtype6], [str, float, float, float, float, float])

    def test_Q6_check_first_and_last_brand(self):
        first_brand = answer_dict['Q6'][0][0]
        last_brand = answer_dict['Q6'][4][0]

        self.assertEqual([first_brand, last_brand], ["Toyota", "Honda"])

    def test_Q7_dim(self):
        self.assertEqual(np.array(answer_dict['Q7'], dtype=object).shape, (7,2))

    def test_Q7_types(self):
        dtype1 = type(answer_dict['Q7'][0][0])
        dtype2 = type(answer_dict['Q7'][0][1])
        self.assertEqual([dtype1, dtype2], [tuple, float])

unittest.main(argv=[''], verbosity=2, exit=False)

# %% [markdown]
# ##Save your answers
#
#
# ##### First, take a moment to evaluate your answers and make sure you have not missed anything
#
# ##### Use the following code to save your answers in pickle format, change the filename using the following format:
# ##### FIRSTNAME_LASTNAME_answers.pkl
# ##### Example: Juan_Perez_answers.pkl
#
# ##### If you are using google colab you can find your file on the left side bar by clicking the folder icon inside the sample_data folder. Remember to upload the pickle file and the notebook to github and submit their URLs to the [google form](https://forms.gle/wWysZEMkoZsjB11Y7).

# %%
answer_dict

# %%
import pickle

file_name = "FIRSTNAME_LASTNAME_answers.pkl"
path = ""

with open(path+file_name, 'wb') as f:
    pickle.dump(answer_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
